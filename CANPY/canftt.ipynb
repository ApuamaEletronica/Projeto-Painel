# %%
import pandas as pd
df = pd.read_csv(r'can.csv', sep=';', dtype=str)
df.columns = ['Identificador','Tamanho','canDATA0','canDATA1','canDATA2','canDATA3','canDATA4','canDATA5','canDATA6','canDATA7']
df.head()
#print(df)
# Out:
#   Identificador Tamanho canDATA0 canDATA1 canDATA2 canDATA3 canDATA4 canDATA5  \
# 0    0x140810FF       8     0x01     0x8E     0x00     0xF6     0x00     0x90
# 1    0x140812FF       8     0x00     0x00     0x20     0x00     0x06     0x01
# 2    0x140812FF       8     0x01     0x08     0x00     0xF5     0x02     0x3E
# 3    0x140812FF       8     0x02     0x02     0x40     0x00     0x00     0x02
# 4    0x140812FF       7     0x04     0x00     0x00     0x02     0xA6     0x00
#
#   canDATA6 canDATA7
# 0     0x00     0x00
# 1     0x35     0x00
# 2     0x00     0x00
# 3     0x42     0x00
# 4     0x01      NaN

# %%
#df.query('Identificador == "0x14080601" & canDATA0 == "0x02"')
#Para cada linha ira realizar a verificação da mensagem
segmentedPacket = []
lastTam = 0
for index, row in df.iterrows():
    #Filtragem de mensagem CAN para simple ft info
    # if row['Identificador'] == "0x14080600":
    #     tpsDEC = int(row['canDATA0'][0:4] + row['canDATA1'][2:4], 16)
    #     print("Valor de TPS(DEC):", tpsDEC/10, end=' ')

    #     mapHEX = row['canDATA2'][0:4] + row['canDATA3'][2:4]
    #     mapDEC = int(row['canDATA2'][0:4] + row['canDATA3'][2:4], 16)
    #     print("Valor de MAP(DEC):", mapDEC/1000, end=' ')

    #     airTempDEC = int(row['canDATA4'][0:4] + row['canDATA5'][2:4], 16)
    #     print("Valor de airTemp(DEC):", airTempDEC/10, end=' ')

    #     engineTempHEX = row['canDATA6'][0:4] + row['canDATA7'][2:4]
    #     engineTempDEC = int(row['canDATA6'][0:4] + row['canDATA7'][2:4], 16)
    #     print("Valor de engineTemp(DEC):", engineTempDEC/10)

    # if row['Identificador'] == "0x14080601":
    #         oilPressureDEC = int(row['canDATA0'][0:4] + row['canDATA1'][2:4], 16)
    #         print("Valor de oilPressure(DEC):", oilPressureDEC/1000, end=' ')

    #         fuelPressureDEC = int(row['canDATA2'][0:4] + row['canDATA3'][2:4], 16)
    #         print("Valor de fuelPressure(DEC):", fuelPressureDEC/1000, end=' ')

    #         waterPressureDEC = int(row['canDATA4'][0:4] + row['canDATA5'][2:4], 16)
    #         print("Valor de waterPressure(DEC):", waterPressureDEC/1000, end=' ')

    #         gearDEC = int(row['canDATA6'][0:4] + row['canDATA7'][2:4], 16)
    #         print("Valor de gear(DEC):", gearDEC)

    # if row['Identificador'] == "0x14080602":
    #         exhaustO2DEC = int(row['canDATA0'][0:4] + row['canDATA1'][2:4], 16)
    #         print("Valor de exhaustO2(DEC):", exhaustO2DEC/1000, end=' ')

    #         rpmDEC = int(row['canDATA2'][0:4] + row['canDATA3'][2:4], 16)
    #         print("Valor de rpm(DEC):", rpmDEC, end=' ')

    #         oilTemperatureDEC = int(row['canDATA4'][0:4] + row['canDATA5'][2:4], 16)
    #         print("Valor de oilTemperature(DEC):", oilTemperatureDEC/1000, end='')

    #         pitLimitDEC = int((row['canDATA6'][0:4] + row['canDATA7'][2:4]),16) #Separa os dados e converte para decimal
    #         print("Valor de pitLimit(DEC):", pitLimitDEC)
    # #Filtragem de mensagem CAN para segmented packet
    if ((row['Identificador'] != "0x14080600") and (row['Identificador'] != "0x14080601") and (row['Identificador'] != "0x14080602") and (row['Identificador'] != "0x14080603") and (row['Identificador'] != "0x14080604") and (row['Identificador'] != "0x14080605") and (row['Identificador'] != "0x14080606") and (row['Identificador'] != "0x14080607")):
        if row['canDATA0'] == "0x00":
            #print("row",row)
            segmentedPacket.append(row)
            segmentedId = int("0x01",16)
            for i in range(index, len(df)):
                if row['Identificador'] == df.iloc[i]['Identificador']  and  int(df.iloc[i]['canDATA0'],16) == segmentedId:
                    #print("df",df.iloc[i])
                    segmentedPacket.append(df.iloc[i])        
                    segmentedId += 1
                if segmentedId == 20: #Limitador de 20, sendo q o max recebido foi 10
                    break
            print(len(segmentedPacket))
            print(segmentedPacket[0])
            print("MeasureID1 = " + segmentedPacket[0]['canDATA3'][0:4] + segmentedPacket[0]['canDATA4'][2:4]+ " Value1 = " + segmentedPacket[0]['canDATA5'][0:4] + segmentedPacket[0]['canDATA6'][2:4])
            #print(segmentedPacket[1])
            print("MeasureID2 = " + segmentedPacket[0]["canDATA7"][0:4] + segmentedPacket[1]["canDATA1"][2:4]+ " Value2 = " + segmentedPacket[1]["canDATA2"][0:4] + (segmentedPacket[1]["canDATA3"][2:4]))
            #print(segmentedPacket[2])
            print("MeasureID3 = " + segmentedPacket[1]["canDATA4"][0:4] + segmentedPacket[1]["canDATA5"][2:4]+ " Value3 = " + segmentedPacket[1]["canDATA6"][0:4] + (segmentedPacket[1]["canDATA7"][2:4]))
            #print(segmentedPacket[3])ok
            print("MeasureID4 = " + segmentedPacket[2]["canDATA1"][0:4] + segmentedPacket[1]["canDATA2"][2:4]+ " Value4 = " + segmentedPacket[2]["canDATA3"][0:4] + (segmentedPacket[1]["canDATA4"][2:4]))
            #print(segmentedPacket[4])
            print("MeasureID5 = " + segmentedPacket[2]["canDATA5"][0:4] + segmentedPacket[1]["canDATA6"][2:4]+ " Value5 = " + segmentedPacket[2]["canDATA7"][0:4] + (segmentedPacket[3]["canDATA1"][2:4]))
            #print(segmentedPacket[5])
            print("MeasureID6 = " + segmentedPacket[3]["canDATA2"][0:4] + segmentedPacket[3]["canDATA3"][2:4]+ " Value6 = " + segmentedPacket[3]["canDATA4"][0:4] + (segmentedPacket[3]["canDATA5"][2:4]))
            #print(segmentedPacket[6])
            print("MeasureID7 = " + segmentedPacket[3]["canDATA6"][0:4] + segmentedPacket[3]["canDATA7"][2:4]+ " Value7 = " + segmentedPacket[4]["canDATA1"][0:4] + (segmentedPacket[4]["canDATA2"][2:4]))
            #print(segmentedPacket[7])
            print("MeasureID8 = " + segmentedPacket[4]["canDATA3"][0:4] + segmentedPacket[4]["canDATA4"][2:4]+ " Value8 = " + segmentedPacket[4]["canDATA5"][0:4] + (segmentedPacket[4]["canDATA6"][2:4]))
            #print(segmentedPacket[8])
            print("MeasureID9 = " + segmentedPacket[4]["canDATA7"][0:4] + segmentedPacket[5]["canDATA1"][2:4]+ " Value9 = " + segmentedPacket[5]["canDATA2"][0:4] + (segmentedPacket[5]["canDATA3"][2:4]))
            #print(segmentedPacket[9])
            print("MeasureID10 = " + segmentedPacket[1]["canDATA4"][0:4] + segmentedPacket[1]["canDATA5"][2:4]+ " Value10 = " + segmentedPacket[1]["canDATA6"][0:4] + (segmentedPacket[1]["canDATA7"][2:4]))
            
            
            #print("MeasureID2 = " + segmentedPacket[0]["canDATA7"][0:4] + segmentedPacket[1]['canDATA1'][2:4]+ " Value2 = " + segmentedPacket[1]['canDATA2'][0:4] + segmentedPacket[1]['canDATA3'][2:4])
            # # print(segmentedPacket[0]['canDATA4'][0:4] + segmentedPacket[1]['canDATA5'][2:4])
            segmentedPacket = []

                    
                    

            # print(row['Identificador'])
            # print("Tamanho total:",int(row['canDATA1'][0:4]+row['canDATA2'][2:4],16))
            # #if row['canDATA3'][0:4]+row['canDATA4'][2:4] == "0x0084":
            # print("MeasureID:", row['canDATA3'][0:4]+row['canDATA4'][2:4], end=' ')
            # print("Data valor:", int(row['canDATA5'][0:4]+row['canDATA6'][2:4],16))
# Out:
# 5
# Identificador    0x140812FF
# Tamanho                   8
# canDATA0               0x00
# canDATA1               0x00
# canDATA2               0x20
# canDATA3               0x00
# canDATA4               0x06
# canDATA5               0x01
# canDATA6               0x35
# canDATA7               0x00
# Name: 1, dtype: object
# MeasureID1 = 0x0006 Value1 = 0x0135
# MeasureID2 = 0x0008 Value2 = 0x00F5
# MeasureID3 = 0x023E Value3 = 0x0000
# 4
# Identificador    0x140813FF
# Tamanho                   8
# canDATA0               0x00
# canDATA1               0x00
# canDATA2               0x14
# canDATA3               0x00
# canDATA4               0x7C
# canDATA5               0x00
# canDATA6               0x01
# canDATA7               0x00
# Name: 6, dtype: object
# MeasureID1 = 0x007C Value1 = 0x0001
# MeasureID2 = 0x007E Value2 = 0x0000
# MeasureID3 = 0x0080 Value3 = 0x0000
# 10
# Identificador    0x140811FF
# Tamanho                   8
# canDATA0               0x00
# canDATA1               0x00
# canDATA2               0x40
# canDATA3               0x00
# canDATA4               0x04
# canDATA5               0xFF
# canDATA6               0x84
# canDATA7               0x00
# Name: 10, dtype: object
# MeasureID1 = 0x0004 Value1 = 0xFF84
# MeasureID2 = 0x0002 Value2 = 0x0032
# MeasureID3 = 0x000A Value3 = 0x02D5
# 2
# Identificador    0x140810FF
# Tamanho                   8
# canDATA0               0x00
# canDATA1               0x00
# canDATA2               0x0C
# canDATA3               0x00
# canDATA4               0x84
# canDATA5               0x00
# canDATA6               0x00
# canDATA7               0x00
# Name: 20, dtype: object
# MeasureID1 = 0x0084 Value1 = 0x0000
# MeasureID2 = 0x008E Value2 = 0x00F6
# MeasureID3 = 0x0090 Value3 = 0x0000
# 10
# Identificador    0x140811FF
# Tamanho                   8
# canDATA0               0x00
# canDATA1               0x00
# canDATA2               0x40
# canDATA3               0x00
# canDATA4               0x04
# canDATA5               0xFF
# canDATA6               0x82
# canDATA7               0x00
# Name: 22, dtype: object
# MeasureID1 = 0x0004 Value1 = 0xFF82
# MeasureID2 = 0x0002 Value2 = 0x0032
# MeasureID3 = 0x000A Value3 = 0x07A3
# 5
# Identificador    0x140812FF
# Tamanho                   8
# canDATA0               0x00
# canDATA1               0x00
# canDATA2               0x20
# canDATA3               0x00
# canDATA4               0x06
# canDATA5               0x01
# canDATA6               0x34
# canDATA7               0x00
# Name: 32, dtype: object
# MeasureID1 = 0x0006 Value1 = 0x0134
# MeasureID2 = 0x0008 Value2 = 0x00F5
# MeasureID3 = 0x023E Value3 = 0x0000
# 4
# Identificador    0x140813FF
# Tamanho                   8
# canDATA0               0x00
# canDATA1               0x00
# canDATA2               0x14
# canDATA3               0x00
# canDATA4               0x7C
# canDATA5               0x00
# canDATA6               0x01
# canDATA7               0x00
# Name: 37, dtype: object
# MeasureID1 = 0x007C Value1 = 0x0001
# MeasureID2 = 0x007E Value2 = 0x0000
# MeasureID3 = 0x0080 Value3 = 0x0000
# 2
# Identificador    0x140810FF
# Tamanho                   8
# canDATA0               0x00
# canDATA1               0x00
# canDATA2               0x0C
# canDATA3               0x00
# canDATA4               0x84
# canDATA5               0x01
# canDATA6               0x99
# canDATA7               0x00
# Name: 41, dtype: object
# MeasureID1 = 0x0084 Value1 = 0x0199
# MeasureID2 = 0x008E Value2 = 0x00F6
# MeasureID3 = 0x0090 Value3 = 0x0000
# 10
# Identificador    0x140811FF
# Tamanho                   8
# canDATA0               0x00
# canDATA1               0x00
# canDATA2               0x40
# canDATA3               0x00
# canDATA4               0x04
# canDATA5               0xFF
# canDATA6               0x82
# canDATA7               0x00
# Name: 43, dtype: object
# MeasureID1 = 0x0004 Value1 = 0xFF82
# MeasureID2 = 0x0002 Value2 = 0x0032
# MeasureID3 = 0x000A Value3 = 0x07DA
# 5
# Identificador    0x140812FF
# Tamanho                   8
# canDATA0               0x00
# canDATA1               0x00
# canDATA2               0x20
# canDATA3               0x00
# canDATA4               0x06
# canDATA5               0x01
# canDATA6               0x34
# canDATA7               0x00
# Name: 53, dtype: object
# MeasureID1 = 0x0006 Value1 = 0x0134
# MeasureID2 = 0x0008 Value2 = 0x00F5
# MeasureID3 = 0x023E Value3 = 0x0000
# 2
# Identificador    0x140810FF
# Tamanho                   8
# canDATA0               0x00
# canDATA1               0x00
# canDATA2               0x0C
# canDATA3               0x00
# canDATA4               0x84
# canDATA5               0x01
# canDATA6               0x97
# canDATA7               0x00
# Name: 58, dtype: object
# MeasureID1 = 0x0084 Value1 = 0x0197
# MeasureID2 = 0x008E Value2 = 0x00F6
# MeasureID3 = 0x0090 Value3 = 0x0000
# 10
# Identificador    0x140811FF
# Tamanho                   8
# canDATA0               0x00
# canDATA1               0x00
# canDATA2               0x40
# canDATA3               0x00
# canDATA4               0x04
# canDATA5               0xFF
# canDATA6               0x82
# canDATA7               0x00
# Name: 60, dtype: object
# MeasureID1 = 0x0004 Value1 = 0xFF82
# MeasureID2 = 0x0002 Value2 = 0x0032
# MeasureID3 = 0x000A Value3 = 0x07CB
# 4
# Identificador    0x140813FF
# Tamanho                   8
# canDATA0               0x00
# canDATA1               0x00
# canDATA2               0x14
# canDATA3               0x00
# canDATA4               0x7C
# canDATA5               0x00
# canDATA6               0x01
# canDATA7               0x00
# Name: 69, dtype: object
# MeasureID1 = 0x007C Value1 = 0x0001
# MeasureID2 = 0x007E Value2 = 0x0000
# MeasureID3 = 0x0080 Value3 = 0x0000
# 5
# Identificador    0x140812FF
# Tamanho                   8
# canDATA0               0x00
# canDATA1               0x00
# canDATA2               0x20
# canDATA3               0x00
# canDATA4               0x06
# canDATA5               0x01
# canDATA6               0x34
# canDATA7               0x00
# Name: 73, dtype: object
# MeasureID1 = 0x0006 Value1 = 0x0134
# MeasureID2 = 0x0008 Value2 = 0x00F5
# MeasureID3 = 0x023E Value3 = 0x0000
# 10
# Identificador    0x140811FF
# Tamanho                   8
# canDATA0               0x00
# canDATA1               0x00
# canDATA2               0x40
# canDATA3               0x00
# canDATA4               0x04
# canDATA5               0xFF
# canDATA6               0x81
# canDATA7               0x00
# Name: 78, dtype: object
# MeasureID1 = 0x0004 Value1 = 0xFF81
# MeasureID2 = 0x0002 Value2 = 0x0033
# MeasureID3 = 0x000A Value3 = 0x07CB
# 2
# Identificador    0x140810FF
# Tamanho                   8
# canDATA0               0x00
# canDATA1               0x00
# canDATA2               0x0C
# canDATA3               0x00
# canDATA4               0x84
# canDATA5               0x01
# canDATA6               0x94
# canDATA7               0x00
# Name: 88, dtype: object
# MeasureID1 = 0x0084 Value1 = 0x0194
# MeasureID2 = 0x008E Value2 = 0x00F6
# MeasureID3 = 0x0090 Value3 = 0x0000
# 5
# Identificador    0x140812FF
# Tamanho                   8
# canDATA0               0x00
# canDATA1               0x00
# canDATA2               0x20
# canDATA3               0x00
# canDATA4               0x06
# canDATA5               0x01
# canDATA6               0x33
# canDATA7               0x00
# Name: 90, dtype: object
# MeasureID1 = 0x0006 Value1 = 0x0133
# MeasureID2 = 0x0008 Value2 = 0x00F5
# MeasureID3 = 0x023E Value3 = 0x0000
# 4
# Identificador    0x140813FF
# Tamanho                   8
# canDATA0               0x00
# canDATA1               0x00
# canDATA2               0x14
# canDATA3               0x00
# canDATA4               0x7C
# canDATA5               0x00
# canDATA6               0x01
# canDATA7               0x00
# Name: 94, dtype: object
# MeasureID1 = 0x007C Value1 = 0x0001
# MeasureID2 = 0x007E Value2 = 0x0000
# MeasureID3 = 0x0080 Value3 = 0x0000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 54
#      52 segmentedId = int("0x01",16)
#      53 for i in range(index, len(df)):
# ---> 54     if row['Identificador'] == df.iloc[i]['Identificador']  and  int(df.iloc[i]['canDATA0'],16) == segmentedId:
#      55         #print("df",df.iloc[i])
#      56         segmentedPacket.append(df.iloc[i])
#      57         segmentedId += 1
#
# File c:\Users\Dantas\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexing.py:1073, in _LocationIndexer.__getitem__(self, key)
#    1070 axis = self.axis or 0
#    1072 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\Dantas\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexing.py:1627, in _iLocIndexer._getitem_axis(self, key, axis)
#    1624 # validate the location
#    1625 self._validate_integer(key, axis)
# -> 1627 return self.obj._ixs(key, axis=axis)
#
# File c:\Users\Dantas\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3718, in DataFrame._ixs(self, i, axis)
#    3716 # if we are a copy, mark as such
#    3717 copy = isinstance(new_mgr.array, np.ndarray) and new_mgr.array.base is None
# -> 3718 result = self._constructor_sliced(new_mgr, name=self.index[i]).__finalize__(
#    3719     self
#    3720 )
#    3721 result._set_is_copy(self, copy=copy)
#    3722 return result
#
# File c:\Users\Dantas\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\series.py:364, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     362         object.__setattr__(self, "_name", name)
#     363     else:
# --> 364         self.name = name
#     365     return
#     367 # we are called internally, so short-circuit
#
# File c:\Users\Dantas\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:5924, in NDFrame.__setattr__(self, name, value)
#    5922     object.__setattr__(self, name, value)
#    5923 elif name in self._metadata:
# -> 5924     object.__setattr__(self, name, value)
#    5925 else:
#    5926     try:
#
# File c:\Users\Dantas\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\series.py:661, in Series.name(self, value)
#     613     """
#     614     Return the name of the Series.
#     615
#    (...)
#     657     'Even Numbers'
#     658     """
#     659     return self._name
# --> 661 @name.setter
#     662 def name(self, value: Hashable) -> None:
#     663     validate_all_hashable(value, error_name=f"{type(self).__name__}.name")
#     664     object.__setattr__(self, "_name", value)
#
# KeyboardInterrupt:
